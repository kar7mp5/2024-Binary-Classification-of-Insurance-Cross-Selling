# %% [markdown]
# ## Load the path

# %%
import os


class Config:
    def __init__(self):
        """Dataset
        Load and process the data.
       
        """
        self.train_path: str = os.path.join(os.getcwd(), "contents", "train_kaggle_here.csv")
        self.test_path: str = os.path.join(os.getcwd(), "contents", "test.csv")
        self.submission_path: str = os.path.join(os.getcwd(), "contents", "sample_submission.csv")

# %% [markdown]
# ## Preprocessing data

# %%
import pandas as pd


class Dataset:
    def __init__(self, path):
        """Dataset
        
        Arg:
            path (str): Data path
        """
        print('Load the data...')
        # read the data
        self.df = pd.read_csv(path)
    
    def head(self, n):
        """Return the first n rows of the DataFrame"""
        return self.df.head(n)

    def preprocessing(self):
        """Preprocess the data
        
        Returns:
            Dataframe: Preprocessed data
        """
        print('Preprocess the data')
        # str to integer; not category
        # TODO: we need to use category
        preprocessed_data = self.df.copy()
        preprocessed_data['Gender'] = preprocessed_data['Gender'].replace(['Female', 'Male'], [0, 1])
        preprocessed_data['Vehicle_Age'] = preprocessed_data['Vehicle_Age'].replace(['< 1 Year', '1-2 Year', '> 2 Years'], [0, 1, 2])
        preprocessed_data['Vehicle_Damage'] = preprocessed_data['Vehicle_Damage'].replace(['No', 'Yes'], [0, 1])

        # data quantization
        try:
            preprocessed_data[['Gender', 'Age', 'Driving_License', 'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Response', 'Policy_Sales_Channel']] = preprocessed_data[['Gender', 'Age', 'Driving_License', 'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Response', 'Policy_Sales_Channel']].astype('uint8')
        except:
            preprocessed_data[['Gender', 'Age', 'Driving_License', 'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Policy_Sales_Channel']] = preprocessed_data[['Gender', 'Age', 'Driving_License', 'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Policy_Sales_Channel']].astype('uint8')

        preprocessed_data[['Vintage', 'Annual_Premium']] = preprocessed_data[['Vintage', 'Annual_Premium']].astype('uint16')
        preprocessed_data['Region_Code'] = preprocessed_data['Region_Code'] * 10
        preprocessed_data['Region_Code'] = preprocessed_data['Region_Code'].astype('uint8')
        print('Finished!')
        
        return preprocessed_data
    
    def preprocessing_category(self):
        """Preprocess the data
        
        Returns:
            Dataframe: Preprocessed data
        """
        print('Preprocess the data')
        preprocessed_data = self.df.copy()

        # Define categorical columns
        categorical_columns = ['Gender', 'Vehicle_Age', 'Vehicle_Damage']

        # Convert the columns to categorical type
        for col in categorical_columns:
            preprocessed_data[col] = preprocessed_data[col].astype('category')

        # Convert numeric columns to appropriate types
        preprocessed_data[['Vintage', 'Annual_Premium']] = preprocessed_data[['Vintage', 'Annual_Premium']].astype('uint16')
        
        # Scaling region code by 10 and converting to uint8
        preprocessed_data['Region_Code'] = (preprocessed_data['Region_Code'] * 10).astype('uint8')

        print('Finished!')
        return preprocessed_data, categorical_columns

# %% [markdown]
# ## Load train data

# %%
# Load the data path
config = Config()

# Preprocessing the data
# train_data = Dataset(config.train_path)
# train_df = train_data.preprocessing()
train_df = pd.read_csv('./contents/train_kaggle_here.csv')

# %% [markdown]
# ## Print data

# %%
train_df.head(5)
# Out:
#    Gender       Age  Driving_License  Region_Code  Previously_Insured  \
# 0       0  1.034863                1           19                   0
# 1       0  0.419763                1           23                   0
# 2       0  0.321777                1           13                   1
# 3       0  0.081266                1            2                   0
# 4       0  1.344238                1           11                   1
#
#    Vehicle_Age  Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 0     0.500000               0       -0.041658                    25
# 1     0.490000               1       -0.003643                   155
# 2     0.500000               0       -0.066025                    14
# 3     0.433566               1       -0.012575                   154
# 4     0.500000               1       -0.003410                     4
#
#     Vintage  ...  Previously_Insured_Vehicle_Damage  \
# 0 -0.554489  ...                                  0
# 1  0.951522  ...                                  1
# 2 -0.200023  ...                                 10
# 3  0.353869  ...                                  1
# 4  0.477025  ...                                 11
#
#    Gender_Driving_License_Previously_Insured  \
# 0                                         10
# 1                                         10
# 2                                         11
# 3                                         10
# 4                                         11
#
#    Gender_Driving_License_Vehicle_Damage  \
# 0                                     10
# 1                                     11
# 2                                     10
# 3                                     11
# 4                                     11
#
#    Gender_Previously_Insured_Vehicle_Damage  \
# 0                                         0
# 1                                         1
# 2                                        10
# 3                                         1
# 4                                        11
#
#    Driving_License_Previously_Insured_Vehicle_Damage  \
# 0                                                100
# 1                                                101
# 2                                                110
# 3                                                101
# 4                                                111
#
#    Gender_Driving_License_Previously_Insured_Vehicle_Damage  \
# 0                                                100
# 1                                                101
# 2                                                110
# 3                                                101
# 4                                                111
#
#    Age_by_Vehicle_Age  Age_by_Driving_License  Age_by_Vehicle_Damage  \
# 0            0.517432                1.034863               0.000000
# 1            0.205684                0.419763               0.419763
# 2            0.160889                0.321777               0.000000
# 3            0.035234                0.081266               0.081266
# 4            0.672119                1.344238               1.344238
#
#    Vehicle_Age_by_Vehicle_Damage
# 0                       0.000000
# 1                       0.490000
# 2                       0.000000
# 3                       0.433566
# 4                       0.500000
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Split data

# %%
from sklearn.model_selection import train_test_split
# train_df = train_df.drop('id', axis=1)

y = train_df['Response']
X = train_df.drop('Response', axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=41)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 train_df = train_df.drop('id', axis=1)
#       4 y = train_df['Response']
#       5 X = train_df.drop('Response', axis=1)
#
# File ~/Projects/2024-Binary-Classification-of-Insurance-Cross-Selling/venv/lib/python3.10/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~/Projects/2024-Binary-Classification-of-Insurance-Cross-Selling/venv/lib/python3.10/site-packages/pandas/core/generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~/Projects/2024-Binary-Classification-of-Insurance-Cross-Selling/venv/lib/python3.10/site-packages/pandas/core/generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~/Projects/2024-Binary-Classification-of-Insurance-Cross-Selling/venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['id'] not found in axis"

# %% [markdown]
# ## Train the LightGBM

# %%
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score

lgbm_model = LGBMClassifier(random_state=41, n_estimators=500)

evals = [(X_test, y_test)]

# 모델 학습
lgbm_model.fit(X_train, 
               y_train,                  
            #    early_stopping_rounds = 100, 
               eval_metric = "logloss", 
               eval_set = evals,
               # random_state=1, 
               verbose=True)


y_pred = lgbm_model.predict(X_test)
auc = roc_auc_score(y_test, y_pred)
print(f"roc auc value: {auc}")
# Out:
# /home/kar7mp5/Projects/2024-Binary-Classification-of-Insurance-Cross-Selling/venv/lib/python3.8/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [1]	valid_0's binary_logloss: 0.354153
# [2]	valid_0's binary_logloss: 0.340275
# [3]	valid_0's binary_logloss: 0.329157
# [4]	valid_0's binary_logloss: 0.319923
# [5]	valid_0's binary_logloss: 0.312375
# [6]	valid_0's binary_logloss: 0.305916
# [7]	valid_0's binary_logloss: 0.300472
# [8]	valid_0's binary_logloss: 0.295756
# [9]	valid_0's binary_logloss: 0.291669
# [10]	valid_0's binary_logloss: 0.288058
# [11]	valid_0's binary_logloss: 0.284902
# [12]	valid_0's binary_logloss: 0.282047
# [13]	valid_0's binary_logloss: 0.279649
# [14]	valid_0's binary_logloss: 0.277573
# [15]	valid_0's binary_logloss: 0.275476
# [16]	valid_0's binary_logloss: 0.273849
# [17]	valid_0's binary_logloss: 0.272207
# [18]	valid_0's binary_logloss: 0.270874
# [19]	valid_0's binary_logloss: 0.269638
# [20]	valid_0's binary_logloss: 0.268453
# [21]	valid_0's binary_logloss: 0.267493
# [22]	valid_0's binary_logloss: 0.266502
# [23]	valid_0's binary_logloss: 0.265674
# [24]	valid_0's binary_logloss: 0.26494
# [25]	valid_0's binary_logloss: 0.264165
# [26]	valid_0's binary_logloss: 0.263569
# [27]	valid_0's binary_logloss: 0.262962
# [28]	valid_0's binary_logloss: 0.262431
# [29]	valid_0's binary_logloss: 0.26189
# [30]	valid_0's binary_logloss: 0.261464
# [31]	valid_0's binary_logloss: 0.261049
# [32]	valid_0's binary_logloss: 0.260658
# [33]	valid_0's binary_logloss: 0.260318
# [34]	valid_0's binary_logloss: 0.259887
# [35]	valid_0's binary_logloss: 0.259599
# [36]	valid_0's binary_logloss: 0.259341
# [37]	valid_0's binary_logloss: 0.259046
# [38]	valid_0's binary_logloss: 0.258829
# [39]	valid_0's binary_logloss: 0.258559
# [40]	valid_0's binary_logloss: 0.258378
# [41]	valid_0's binary_logloss: 0.258154
# [42]	valid_0's binary_logloss: 0.258009
# [43]	valid_0's binary_logloss: 0.257863
# [44]	valid_0's binary_logloss: 0.257748
# [45]	valid_0's binary_logloss: 0.257563
# [46]	valid_0's binary_logloss: 0.257456
# [47]	valid_0's binary_logloss: 0.257341
# [48]	valid_0's binary_logloss: 0.257231
# [49]	valid_0's binary_logloss: 0.257112
# [50]	valid_0's binary_logloss: 0.256976
# [51]	valid_0's binary_logloss: 0.256891
# [52]	valid_0's binary_logloss: 0.256814
# [53]	valid_0's binary_logloss: 0.256725
# [54]	valid_0's binary_logloss: 0.256613
# [55]	valid_0's binary_logloss: 0.256545
# [56]	valid_0's binary_logloss: 0.256477
# [57]	valid_0's binary_logloss: 0.256422
# [58]	valid_0's binary_logloss: 0.256364
# [59]	valid_0's binary_logloss: 0.256284
# [60]	valid_0's binary_logloss: 0.25623
# [61]	valid_0's binary_logloss: 0.256183
# [62]	valid_0's binary_logloss: 0.256134
# [63]	valid_0's binary_logloss: 0.256086
# [64]	valid_0's binary_logloss: 0.256048
# [65]	valid_0's binary_logloss: 0.255956
# [66]	valid_0's binary_logloss: 0.255896
# [67]	valid_0's binary_logloss: 0.255793
# [68]	valid_0's binary_logloss: 0.25576
# [69]	valid_0's binary_logloss: 0.255728
# [70]	valid_0's binary_logloss: 0.255679
# [71]	valid_0's binary_logloss: 0.255643
# [72]	valid_0's binary_logloss: 0.255606
# [73]	valid_0's binary_logloss: 0.255576
# [74]	valid_0's binary_logloss: 0.255455
# [75]	valid_0's binary_logloss: 0.255428
# [76]	valid_0's binary_logloss: 0.255404
# [77]	valid_0's binary_logloss: 0.255365
# [78]	valid_0's binary_logloss: 0.255331
# [79]	valid_0's binary_logloss: 0.255257
# [80]	valid_0's binary_logloss: 0.255156
# [81]	valid_0's binary_logloss: 0.255118
# [82]	valid_0's binary_logloss: 0.255077
# [83]	valid_0's binary_logloss: 0.255052
# [84]	valid_0's binary_logloss: 0.255032
# [85]	valid_0's binary_logloss: 0.254999
# [86]	valid_0's binary_logloss: 0.254954
# [87]	valid_0's binary_logloss: 0.25491
# [88]	valid_0's binary_logloss: 0.254854
# [89]	valid_0's binary_logloss: 0.254761
# [90]	valid_0's binary_logloss: 0.254731
# [91]	valid_0's binary_logloss: 0.25471
# [92]	valid_0's binary_logloss: 0.25468
# [93]	valid_0's binary_logloss: 0.254656
# [94]	valid_0's binary_logloss: 0.254636
# [95]	valid_0's binary_logloss: 0.25461
# [96]	valid_0's binary_logloss: 0.254526
# [97]	valid_0's binary_logloss: 0.254503
# [98]	valid_0's binary_logloss: 0.254479
# [99]	valid_0's binary_logloss: 0.25445
# [100]	valid_0's binary_logloss: 0.254405
# [101]	valid_0's binary_logloss: 0.254389
# [102]	valid_0's binary_logloss: 0.254375
# [103]	valid_0's binary_logloss: 0.254343
# [104]	valid_0's binary_logloss: 0.254322
# [105]	valid_0's binary_logloss: 0.2543
# [106]	valid_0's binary_logloss: 0.254265
# [107]	valid_0's binary_logloss: 0.254197
# [108]	valid_0's binary_logloss: 0.254131
# [109]	valid_0's binary_logloss: 0.254104
# [110]	valid_0's binary_logloss: 0.254087
# [111]	valid_0's binary_logloss: 0.254074
# [112]	valid_0's binary_logloss: 0.254046
# [113]	valid_0's binary_logloss: 0.253992
# [114]	valid_0's binary_logloss: 0.253936
# [115]	valid_0's binary_logloss: 0.253929
# [116]	valid_0's binary_logloss: 0.253911
# [117]	valid_0's binary_logloss: 0.253896
# [118]	valid_0's binary_logloss: 0.253882
# [119]	valid_0's binary_logloss: 0.253832
# [120]	valid_0's binary_logloss: 0.253812
# [121]	valid_0's binary_logloss: 0.253797
# [122]	valid_0's binary_logloss: 0.253774
# [123]	valid_0's binary_logloss: 0.253766
# [124]	valid_0's binary_logloss: 0.253755
# [125]	valid_0's binary_logloss: 0.253738
# [126]	valid_0's binary_logloss: 0.253726
# [127]	valid_0's binary_logloss: 0.253686
# [128]	valid_0's binary_logloss: 0.253664
# [129]	valid_0's binary_logloss: 0.253641
# [130]	valid_0's binary_logloss: 0.253638
# [131]	valid_0's binary_logloss: 0.25364
# [132]	valid_0's binary_logloss: 0.253631
# [133]	valid_0's binary_logloss: 0.253621
# [134]	valid_0's binary_logloss: 0.253597
# [135]	valid_0's binary_logloss: 0.253547
# [136]	valid_0's binary_logloss: 0.253505
# [137]	valid_0's binary_logloss: 0.253488
# [138]	valid_0's binary_logloss: 0.253475
# [139]	valid_0's binary_logloss: 0.253467
# [140]	valid_0's binary_logloss: 0.253428
# [141]	valid_0's binary_logloss: 0.25341
# [142]	valid_0's binary_logloss: 0.253404
# [143]	valid_0's binary_logloss: 0.25337
# [144]	valid_0's binary_logloss: 0.253355
# [145]	valid_0's binary_logloss: 0.253323
# [146]	valid_0's binary_logloss: 0.253309
# [147]	valid_0's binary_logloss: 0.253295
# [148]	valid_0's binary_logloss: 0.253292
# [149]	valid_0's binary_logloss: 0.253275
# [150]	valid_0's binary_logloss: 0.253251
# [151]	valid_0's binary_logloss: 0.253218
# [152]	valid_0's binary_logloss: 0.253203
# [153]	valid_0's binary_logloss: 0.253231
# [154]	valid_0's binary_logloss: 0.253313
# [155]	valid_0's binary_logloss: 0.253229
# [156]	valid_0's binary_logloss: 0.253228
# [157]	valid_0's binary_logloss: 0.253227
# [158]	valid_0's binary_logloss: 0.253242
# [159]	valid_0's binary_logloss: 0.253335
# [160]	valid_0's binary_logloss: 0.253246
# [161]	valid_0's binary_logloss: 0.25325
# [162]	valid_0's binary_logloss: 0.253245
# [163]	valid_0's binary_logloss: 0.253313
# [164]	valid_0's binary_logloss: 0.25324
# [165]	valid_0's binary_logloss: 0.25323
# [166]	valid_0's binary_logloss: 0.253225
# [167]	valid_0's binary_logloss: 0.253207
# [168]	valid_0's binary_logloss: 0.253181
# [169]	valid_0's binary_logloss: 0.253165
# [170]	valid_0's binary_logloss: 0.253153
# [171]	valid_0's binary_logloss: 0.253135
# [172]	valid_0's binary_logloss: 0.253123
# [173]	valid_0's binary_logloss: 0.25312
# [174]	valid_0's binary_logloss: 0.253108
# [175]	valid_0's binary_logloss: 0.253086
# [176]	valid_0's binary_logloss: 0.253062
# [177]	valid_0's binary_logloss: 0.253051
# [178]	valid_0's binary_logloss: 0.25304
# [179]	valid_0's binary_logloss: 0.253034
# [180]	valid_0's binary_logloss: 0.25303
# [181]	valid_0's binary_logloss: 0.253009
# [182]	valid_0's binary_logloss: 0.252988
# [183]	valid_0's binary_logloss: 0.252986
# [184]	valid_0's binary_logloss: 0.252983
# [185]	valid_0's binary_logloss: 0.252968
# [186]	valid_0's binary_logloss: 0.252946
# [187]	valid_0's binary_logloss: 0.25293
# [188]	valid_0's binary_logloss: 0.252923
# [189]	valid_0's binary_logloss: 0.252915
# [190]	valid_0's binary_logloss: 0.252908
# [191]	valid_0's binary_logloss: 0.253033
# [192]	valid_0's binary_logloss: 0.252948
# [193]	valid_0's binary_logloss: 0.252911
# [194]	valid_0's binary_logloss: 0.252901
# [195]	valid_0's binary_logloss: 0.252888
# [196]	valid_0's binary_logloss: 0.252877
# [197]	valid_0's binary_logloss: 0.252875
# [198]	valid_0's binary_logloss: 0.252858
# [199]	valid_0's binary_logloss: 0.25285
# [200]	valid_0's binary_logloss: 0.252837
# [201]	valid_0's binary_logloss: 0.252829
# [202]	valid_0's binary_logloss: 0.252823
# [203]	valid_0's binary_logloss: 0.252822
# [204]	valid_0's binary_logloss: 0.252805
# [205]	valid_0's binary_logloss: 0.252778
# [206]	valid_0's binary_logloss: 0.252769
# [207]	valid_0's binary_logloss: 0.252746
# [208]	valid_0's binary_logloss: 0.252728
# [209]	valid_0's binary_logloss: 0.252723
# [210]	valid_0's binary_logloss: 0.252722
# [211]	valid_0's binary_logloss: 0.252718
# [212]	valid_0's binary_logloss: 0.25271
# [213]	valid_0's binary_logloss: 0.252707
# [214]	valid_0's binary_logloss: 0.252698
# [215]	valid_0's binary_logloss: 0.252684
# [216]	valid_0's binary_logloss: 0.252676
# [217]	valid_0's binary_logloss: 0.252676
# [218]	valid_0's binary_logloss: 0.252658
# [219]	valid_0's binary_logloss: 0.252656
# [220]	valid_0's binary_logloss: 0.252647
# [221]	valid_0's binary_logloss: 0.252637
# [222]	valid_0's binary_logloss: 0.252618
# [223]	valid_0's binary_logloss: 0.252603
# [224]	valid_0's binary_logloss: 0.252586
# [225]	valid_0's binary_logloss: 0.252573
# [226]	valid_0's binary_logloss: 0.252568
# [227]	valid_0's binary_logloss: 0.252567
# [228]	valid_0's binary_logloss: 0.252563
# [229]	valid_0's binary_logloss: 0.252556
# [230]	valid_0's binary_logloss: 0.252554
# [231]	valid_0's binary_logloss: 0.252552
# [232]	valid_0's binary_logloss: 0.252544
# [233]	valid_0's binary_logloss: 0.252533
# [234]	valid_0's binary_logloss: 0.252525
# [235]	valid_0's binary_logloss: 0.252518
# [236]	valid_0's binary_logloss: 0.252517
# [237]	valid_0's binary_logloss: 0.252503
# [238]	valid_0's binary_logloss: 0.252494
# [239]	valid_0's binary_logloss: 0.252489
# [240]	valid_0's binary_logloss: 0.252475
# [241]	valid_0's binary_logloss: 0.25247
# [242]	valid_0's binary_logloss: 0.252459
# [243]	valid_0's binary_logloss: 0.252453
# [244]	valid_0's binary_logloss: 0.25244
# [245]	valid_0's binary_logloss: 0.252435
# [246]	valid_0's binary_logloss: 0.252428
# [247]	valid_0's binary_logloss: 0.252423
# [248]	valid_0's binary_logloss: 0.252417
# [249]	valid_0's binary_logloss: 0.252402
# [250]	valid_0's binary_logloss: 0.252396
# [251]	valid_0's binary_logloss: 0.252382
# [252]	valid_0's binary_logloss: 0.252381
# [253]	valid_0's binary_logloss: 0.252368
# [254]	valid_0's binary_logloss: 0.252367
# [255]	valid_0's binary_logloss: 0.252363
# [256]	valid_0's binary_logloss: 0.252362
# [257]	valid_0's binary_logloss: 0.25236
# [258]	valid_0's binary_logloss: 0.25236
# [259]	valid_0's binary_logloss: 0.252349
# [260]	valid_0's binary_logloss: 0.252342
# [261]	valid_0's binary_logloss: 0.252336
# [262]	valid_0's binary_logloss: 0.252329
# [263]	valid_0's binary_logloss: 0.252322
# [264]	valid_0's binary_logloss: 0.252321
# [265]	valid_0's binary_logloss: 0.252315
# [266]	valid_0's binary_logloss: 0.25231
# [267]	valid_0's binary_logloss: 0.25231
# [268]	valid_0's binary_logloss: 0.25231
# [269]	valid_0's binary_logloss: 0.2523
# [270]	valid_0's binary_logloss: 0.252297
# [271]	valid_0's binary_logloss: 0.252296
# [272]	valid_0's binary_logloss: 0.252293
# [273]	valid_0's binary_logloss: 0.252288
# [274]	valid_0's binary_logloss: 0.252284
# [275]	valid_0's binary_logloss: 0.252274
# [276]	valid_0's binary_logloss: 0.252275
# [277]	valid_0's binary_logloss: 0.252269
# [278]	valid_0's binary_logloss: 0.252264
# [279]	valid_0's binary_logloss: 0.252259
# [280]	valid_0's binary_logloss: 0.252253
# [281]	valid_0's binary_logloss: 0.252242
# [282]	valid_0's binary_logloss: 0.252235
# [283]	valid_0's binary_logloss: 0.252228
# [284]	valid_0's binary_logloss: 0.252227
# [285]	valid_0's binary_logloss: 0.25222
# [286]	valid_0's binary_logloss: 0.252213
# [287]	valid_0's binary_logloss: 0.252205
# [288]	valid_0's binary_logloss: 0.252199
# [289]	valid_0's binary_logloss: 0.252196
# [290]	valid_0's binary_logloss: 0.252192
# [291]	valid_0's binary_logloss: 0.252188
# [292]	valid_0's binary_logloss: 0.252188
# [293]	valid_0's binary_logloss: 0.252178
# [294]	valid_0's binary_logloss: 0.252177
# [295]	valid_0's binary_logloss: 0.252176
# [296]	valid_0's binary_logloss: 0.252163
# [297]	valid_0's binary_logloss: 0.252154
# [298]	valid_0's binary_logloss: 0.252153
# [299]	valid_0's binary_logloss: 0.252146
# [300]	valid_0's binary_logloss: 0.252142
# [301]	valid_0's binary_logloss: 0.252136
# [302]	valid_0's binary_logloss: 0.252131
# [303]	valid_0's binary_logloss: 0.252123
# [304]	valid_0's binary_logloss: 0.252114
# [305]	valid_0's binary_logloss: 0.252104
# [306]	valid_0's binary_logloss: 0.2521
# [307]	valid_0's binary_logloss: 0.252097
# [308]	valid_0's binary_logloss: 0.252097
# [309]	valid_0's binary_logloss: 0.252097
# [310]	valid_0's binary_logloss: 0.252095
# [311]	valid_0's binary_logloss: 0.252096
# [312]	valid_0's binary_logloss: 0.2521
# [313]	valid_0's binary_logloss: 0.2521
# [314]	valid_0's binary_logloss: 0.252096
# [315]	valid_0's binary_logloss: 0.252103
# [316]	valid_0's binary_logloss: 0.252122
# [317]	valid_0's binary_logloss: 0.252108
# [318]	valid_0's binary_logloss: 0.252103
# [319]	valid_0's binary_logloss: 0.252171
# [320]	valid_0's binary_logloss: 0.252111
# [321]	valid_0's binary_logloss: 0.252125
# [322]	valid_0's binary_logloss: 0.252395
# [323]	valid_0's binary_logloss: 0.252155
# [324]	valid_0's binary_logloss: 0.252304
# [325]	valid_0's binary_logloss: 0.252142
# [326]	valid_0's binary_logloss: 0.252325
# [327]	valid_0's binary_logloss: 0.25216
# [328]	valid_0's binary_logloss: 0.25229
# [329]	valid_0's binary_logloss: 0.252184
# [330]	valid_0's binary_logloss: 0.252175
# [331]	valid_0's binary_logloss: 0.252169
# [332]	valid_0's binary_logloss: 0.252213
# [333]	valid_0's binary_logloss: 0.25221
# [334]	valid_0's binary_logloss: 0.252234
# [335]	valid_0's binary_logloss: 0.252241
# [336]	valid_0's binary_logloss: 0.252993
# [337]	valid_0's binary_logloss: 0.252267
# [338]	valid_0's binary_logloss: 0.252271
# [339]	valid_0's binary_logloss: 0.252286
# [340]	valid_0's binary_logloss: 0.252237
# [341]	valid_0's binary_logloss: 0.252236
# [342]	valid_0's binary_logloss: 0.252234
# [343]	valid_0's binary_logloss: 0.252226
# [344]	valid_0's binary_logloss: 0.252255
# [345]	valid_0's binary_logloss: 0.25224
# [346]	valid_0's binary_logloss: 0.252346
# [347]	valid_0's binary_logloss: 0.25225
# [348]	valid_0's binary_logloss: 0.252279
# [349]	valid_0's binary_logloss: 0.252375
# [350]	valid_0's binary_logloss: 0.252514
# [351]	valid_0's binary_logloss: 0.252327
# [352]	valid_0's binary_logloss: 0.25239
# [353]	valid_0's binary_logloss: 0.252447
# [354]	valid_0's binary_logloss: 0.252381
# [355]	valid_0's binary_logloss: 0.25227
# [356]	valid_0's binary_logloss: 0.252268
# [357]	valid_0's binary_logloss: 0.252259
# [358]	valid_0's binary_logloss: 0.252255
# [359]	valid_0's binary_logloss: 0.252247
# [360]	valid_0's binary_logloss: 0.252246
# [361]	valid_0's binary_logloss: 0.252239
# [362]	valid_0's binary_logloss: 0.252239
# [363]	valid_0's binary_logloss: 0.252238
# [364]	valid_0's binary_logloss: 0.252348
# [365]	valid_0's binary_logloss: 0.252303
# [366]	valid_0's binary_logloss: 0.25236
# [367]	valid_0's binary_logloss: 0.252334
# [368]	valid_0's binary_logloss: 0.252312
# [369]	valid_0's binary_logloss: 0.252253
# [370]	valid_0's binary_logloss: 0.252284
# [371]	valid_0's binary_logloss: 0.252267
# [372]	valid_0's binary_logloss: 0.252422
# [373]	valid_0's binary_logloss: 0.252294
# [374]	valid_0's binary_logloss: 0.252296
# [375]	valid_0's binary_logloss: 0.252258
# [376]	valid_0's binary_logloss: 0.252447
# [377]	valid_0's binary_logloss: 0.252257
# [378]	valid_0's binary_logloss: 0.252288
# [379]	valid_0's binary_logloss: 0.252241
# [380]	valid_0's binary_logloss: 0.252336
# [381]	valid_0's binary_logloss: 0.252434
# [382]	valid_0's binary_logloss: 0.252328
# [383]	valid_0's binary_logloss: 0.252334
# [384]	valid_0's binary_logloss: 0.252391
# [385]	valid_0's binary_logloss: 0.25224
# [386]	valid_0's binary_logloss: 0.252434
# [387]	valid_0's binary_logloss: 0.252327
# [388]	valid_0's binary_logloss: 0.252565
# [389]	valid_0's binary_logloss: 0.252335
# [390]	valid_0's binary_logloss: 0.252357
# [391]	valid_0's binary_logloss: 0.252356
# [392]	valid_0's binary_logloss: 0.253046
# [393]	valid_0's binary_logloss: 0.252835
# [394]	valid_0's binary_logloss: 0.252399
# [395]	valid_0's binary_logloss: 0.252397
# [396]	valid_0's binary_logloss: 0.252392
# [397]	valid_0's binary_logloss: 0.252386
# [398]	valid_0's binary_logloss: 0.252379
# [399]	valid_0's binary_logloss: 0.252372
# [400]	valid_0's binary_logloss: 0.252365
# [401]	valid_0's binary_logloss: 0.252362
# [402]	valid_0's binary_logloss: 0.252357
# [403]	valid_0's binary_logloss: 0.252349
# [404]	valid_0's binary_logloss: 0.252342
# [405]	valid_0's binary_logloss: 0.25234
# [406]	valid_0's binary_logloss: 0.252336
# [407]	valid_0's binary_logloss: 0.252331
# [408]	valid_0's binary_logloss: 0.252329
# [409]	valid_0's binary_logloss: 0.252323
# [410]	valid_0's binary_logloss: 0.25232
# [411]	valid_0's binary_logloss: 0.252317
# [412]	valid_0's binary_logloss: 0.252317
# [413]	valid_0's binary_logloss: 0.252309
# [414]	valid_0's binary_logloss: 0.252309
# [415]	valid_0's binary_logloss: 0.252307
# [416]	valid_0's binary_logloss: 0.252305
# [417]	valid_0's binary_logloss: 0.252301
# [418]	valid_0's binary_logloss: 0.252298
# [419]	valid_0's binary_logloss: 0.252295
# [420]	valid_0's binary_logloss: 0.252369
# [421]	valid_0's binary_logloss: 0.252306
# [422]	valid_0's binary_logloss: 0.252306
# [423]	valid_0's binary_logloss: 0.252306
# [424]	valid_0's binary_logloss: 0.252305
# [425]	valid_0's binary_logloss: 0.252301
# [426]	valid_0's binary_logloss: 0.252514
# [427]	valid_0's binary_logloss: 0.252304
# [428]	valid_0's binary_logloss: 0.252303
# [429]	valid_0's binary_logloss: 0.252302
# [430]	valid_0's binary_logloss: 0.2523
# [431]	valid_0's binary_logloss: 0.252297
# [432]	valid_0's binary_logloss: 0.252293
# [433]	valid_0's binary_logloss: 0.252289
# [434]	valid_0's binary_logloss: 0.252281
# [435]	valid_0's binary_logloss: 0.252279
# [436]	valid_0's binary_logloss: 0.252276
# [437]	valid_0's binary_logloss: 0.252274
# [438]	valid_0's binary_logloss: 0.252273
# [439]	valid_0's binary_logloss: 0.252272
# [440]	valid_0's binary_logloss: 0.252262
# [441]	valid_0's binary_logloss: 0.252259
# [442]	valid_0's binary_logloss: 0.252255
# [443]	valid_0's binary_logloss: 0.252252
# [444]	valid_0's binary_logloss: 0.252248
# [445]	valid_0's binary_logloss: 0.252242
# [446]	valid_0's binary_logloss: 0.252242
# [447]	valid_0's binary_logloss: 0.252242
# [448]	valid_0's binary_logloss: 0.252245
# [449]	valid_0's binary_logloss: 0.252244
# [450]	valid_0's binary_logloss: 0.252423
# [451]	valid_0's binary_logloss: 0.252486
# [452]	valid_0's binary_logloss: 0.252542
# [453]	valid_0's binary_logloss: 0.252446
# [454]	valid_0's binary_logloss: 0.252308
# [455]	valid_0's binary_logloss: 0.252552
# [456]	valid_0's binary_logloss: 0.2524
# [457]	valid_0's binary_logloss: 0.252404
# [458]	valid_0's binary_logloss: 0.252656
# [459]	valid_0's binary_logloss: 0.25243
# [460]	valid_0's binary_logloss: 0.252533
# [461]	valid_0's binary_logloss: 0.252541
# [462]	valid_0's binary_logloss: 0.252276
# [463]	valid_0's binary_logloss: 0.252697
# [464]	valid_0's binary_logloss: 0.252382
# [465]	valid_0's binary_logloss: 0.252377
# [466]	valid_0's binary_logloss: 0.252375
# [467]	valid_0's binary_logloss: 0.252375
# [468]	valid_0's binary_logloss: 0.252373
# [469]	valid_0's binary_logloss: 0.252371
# [470]	valid_0's binary_logloss: 0.252367
# [471]	valid_0's binary_logloss: 0.252364
# [472]	valid_0's binary_logloss: 0.252361
# [473]	valid_0's binary_logloss: 0.252361
# [474]	valid_0's binary_logloss: 0.252361
# [475]	valid_0's binary_logloss: 0.25236
# [476]	valid_0's binary_logloss: 0.252356
# [477]	valid_0's binary_logloss: 0.252576
# [478]	valid_0's binary_logloss: 0.252308
# [479]	valid_0's binary_logloss: 0.252591
# [480]	valid_0's binary_logloss: 0.25271
# [481]	valid_0's binary_logloss: 0.252274
# [482]	valid_0's binary_logloss: 0.252273
# [483]	valid_0's binary_logloss: 0.252271
# [484]	valid_0's binary_logloss: 0.25227
# [485]	valid_0's binary_logloss: 0.252268
# [486]	valid_0's binary_logloss: 0.252261
# [487]	valid_0's binary_logloss: 0.252257
# [488]	valid_0's binary_logloss: 0.252253
# [489]	valid_0's binary_logloss: 0.252252
# [490]	valid_0's binary_logloss: 0.252251
# [491]	valid_0's binary_logloss: 0.25225
# [492]	valid_0's binary_logloss: 0.252248
# [493]	valid_0's binary_logloss: 0.252247
# [494]	valid_0's binary_logloss: 0.252247
# [495]	valid_0's binary_logloss: 0.252244
# [496]	valid_0's binary_logloss: 0.252243
# [497]	valid_0's binary_logloss: 0.252243
# [498]	valid_0's binary_logloss: 0.252405
# [499]	valid_0's binary_logloss: 0.252417
# [500]	valid_0's binary_logloss: 0.252261
# roc auc value: 0.5472248445393074

# %% [markdown]
# ## Save the model

# %%
import joblib

joblib.dump(lgbm_model, 'models/lgbm_model.pkl')
# Out:
# ['models/lgbm_model.pkl']

# %%
import joblib

lgbm_model = joblib.load('models/lgbm_model.pkl')

# %% [markdown]
# ## Train the Xgboost

# %%
import xgboost as xgb
from sklearn.metrics import roc_auc_score

# Define the XGBoost classifier model
xgboost_model = xgb.XGBClassifier(
    n_estimators=500,
    max_depth=16,
    learning_rate=0.01,
    random_state=41, 
    objective='binary:logistic',
)

# Prepare the evaluation metric and monitoring set
eval_set = [(X_train, y_train), (X_test, y_test)]

# Fit the model with evaluation metrics
xgboost_model.fit(
    X_train, 
    y_train, 
    eval_set=eval_set,
    # eval_metric="logloss",  # Use a single string instead of a list
    verbose=True  # Prints evaluation results after every boosting round
)

# Evaluate the model on the test data (optional)
y_pred = xgboost_model.predict(X_test)
auc = roc_auc_score(y_test, y_pred)
print(f"roc auc value: {auc}")
# Out:
# [0]	validation_0-logloss:0.38378	validation_1-logloss:0.38325
# [1]	validation_0-logloss:0.38202	validation_1-logloss:0.38153
# [2]	validation_0-logloss:0.38030	validation_1-logloss:0.37985
# [3]	validation_0-logloss:0.37860	validation_1-logloss:0.37819
# [4]	validation_0-logloss:0.37694	validation_1-logloss:0.37657
# [5]	validation_0-logloss:0.37530	validation_1-logloss:0.37497
# [6]	validation_0-logloss:0.37370	validation_1-logloss:0.37340
# [7]	validation_0-logloss:0.37212	validation_1-logloss:0.37186
# [8]	validation_0-logloss:0.37056	validation_1-logloss:0.37034
# [9]	validation_0-logloss:0.36903	validation_1-logloss:0.36885
# [10]	validation_0-logloss:0.36753	validation_1-logloss:0.36738
# [11]	validation_0-logloss:0.36605	validation_1-logloss:0.36594
# [12]	validation_0-logloss:0.36460	validation_1-logloss:0.36452
# [13]	validation_0-logloss:0.36317	validation_1-logloss:0.36313
# [14]	validation_0-logloss:0.36176	validation_1-logloss:0.36175
# [15]	validation_0-logloss:0.36038	validation_1-logloss:0.36040
# [16]	validation_0-logloss:0.35901	validation_1-logloss:0.35907
# [17]	validation_0-logloss:0.35767	validation_1-logloss:0.35776
# [18]	validation_0-logloss:0.35635	validation_1-logloss:0.35648
# [19]	validation_0-logloss:0.35505	validation_1-logloss:0.35520
# [20]	validation_0-logloss:0.35377	validation_1-logloss:0.35396
# [21]	validation_0-logloss:0.35250	validation_1-logloss:0.35273
# [22]	validation_0-logloss:0.35126	validation_1-logloss:0.35152
# [23]	validation_0-logloss:0.35004	validation_1-logloss:0.35032
# [24]	validation_0-logloss:0.34883	validation_1-logloss:0.34915
# [25]	validation_0-logloss:0.34764	validation_1-logloss:0.34799
# [26]	validation_0-logloss:0.34647	validation_1-logloss:0.34685
# [27]	validation_0-logloss:0.34531	validation_1-logloss:0.34572
# [28]	validation_0-logloss:0.34418	validation_1-logloss:0.34462
# [29]	validation_0-logloss:0.34305	validation_1-logloss:0.34353
# [30]	validation_0-logloss:0.34194	validation_1-logloss:0.34244
# [31]	validation_0-logloss:0.34085	validation_1-logloss:0.34139
# [32]	validation_0-logloss:0.33978	validation_1-logloss:0.34034
# [33]	validation_0-logloss:0.33872	validation_1-logloss:0.33932
# [34]	validation_0-logloss:0.33768	validation_1-logloss:0.33830
# [35]	validation_0-logloss:0.33665	validation_1-logloss:0.33730
# [36]	validation_0-logloss:0.33563	validation_1-logloss:0.33631
# [37]	validation_0-logloss:0.33463	validation_1-logloss:0.33534
# [38]	validation_0-logloss:0.33364	validation_1-logloss:0.33438
# [39]	validation_0-logloss:0.33266	validation_1-logloss:0.33344
# [40]	validation_0-logloss:0.33171	validation_1-logloss:0.33250
# [41]	validation_0-logloss:0.33076	validation_1-logloss:0.33159
# [42]	validation_0-logloss:0.32982	validation_1-logloss:0.33068
# [43]	validation_0-logloss:0.32890	validation_1-logloss:0.32978
# [44]	validation_0-logloss:0.32798	validation_1-logloss:0.32890
# [45]	validation_0-logloss:0.32708	validation_1-logloss:0.32803
# [46]	validation_0-logloss:0.32620	validation_1-logloss:0.32717
# [47]	validation_0-logloss:0.32532	validation_1-logloss:0.32633
# [48]	validation_0-logloss:0.32445	validation_1-logloss:0.32549
# [49]	validation_0-logloss:0.32360	validation_1-logloss:0.32466
# [50]	validation_0-logloss:0.32276	validation_1-logloss:0.32385
# [51]	validation_0-logloss:0.32193	validation_1-logloss:0.32305
# [52]	validation_0-logloss:0.32111	validation_1-logloss:0.32226
# [53]	validation_0-logloss:0.32030	validation_1-logloss:0.32148
# [54]	validation_0-logloss:0.31950	validation_1-logloss:0.32071
# [55]	validation_0-logloss:0.31871	validation_1-logloss:0.31995
# [56]	validation_0-logloss:0.31793	validation_1-logloss:0.31920
# [57]	validation_0-logloss:0.31717	validation_1-logloss:0.31846
# [58]	validation_0-logloss:0.31641	validation_1-logloss:0.31773
# [59]	validation_0-logloss:0.31566	validation_1-logloss:0.31701
# [60]	validation_0-logloss:0.31493	validation_1-logloss:0.31630
# [61]	validation_0-logloss:0.31420	validation_1-logloss:0.31560
# [62]	validation_0-logloss:0.31348	validation_1-logloss:0.31491
# [63]	validation_0-logloss:0.31277	validation_1-logloss:0.31422
# [64]	validation_0-logloss:0.31207	validation_1-logloss:0.31355
# [65]	validation_0-logloss:0.31138	validation_1-logloss:0.31289
# [66]	validation_0-logloss:0.31069	validation_1-logloss:0.31223
# [67]	validation_0-logloss:0.31002	validation_1-logloss:0.31158
# [68]	validation_0-logloss:0.30935	validation_1-logloss:0.31094
# [69]	validation_0-logloss:0.30869	validation_1-logloss:0.31031
# [70]	validation_0-logloss:0.30804	validation_1-logloss:0.30969
# [71]	validation_0-logloss:0.30739	validation_1-logloss:0.30907
# [72]	validation_0-logloss:0.30676	validation_1-logloss:0.30846
# [73]	validation_0-logloss:0.30613	validation_1-logloss:0.30786
# [74]	validation_0-logloss:0.30551	validation_1-logloss:0.30727
# [75]	validation_0-logloss:0.30490	validation_1-logloss:0.30668
# [76]	validation_0-logloss:0.30430	validation_1-logloss:0.30611
# [77]	validation_0-logloss:0.30371	validation_1-logloss:0.30554
# [78]	validation_0-logloss:0.30311	validation_1-logloss:0.30497
# [79]	validation_0-logloss:0.30252	validation_1-logloss:0.30441
# [80]	validation_0-logloss:0.30195	validation_1-logloss:0.30386
# [81]	validation_0-logloss:0.30138	validation_1-logloss:0.30332
# [82]	validation_0-logloss:0.30081	validation_1-logloss:0.30278
# [83]	validation_0-logloss:0.30025	validation_1-logloss:0.30225
# [84]	validation_0-logloss:0.29971	validation_1-logloss:0.30172
# [85]	validation_0-logloss:0.29917	validation_1-logloss:0.30121
# [86]	validation_0-logloss:0.29863	validation_1-logloss:0.30070
# [87]	validation_0-logloss:0.29810	validation_1-logloss:0.30019
# [88]	validation_0-logloss:0.29758	validation_1-logloss:0.29970
# [89]	validation_0-logloss:0.29706	validation_1-logloss:0.29921
# [90]	validation_0-logloss:0.29655	validation_1-logloss:0.29872
# [91]	validation_0-logloss:0.29604	validation_1-logloss:0.29824
# [92]	validation_0-logloss:0.29554	validation_1-logloss:0.29776
# [93]	validation_0-logloss:0.29505	validation_1-logloss:0.29730
# [94]	validation_0-logloss:0.29456	validation_1-logloss:0.29683
# [95]	validation_0-logloss:0.29407	validation_1-logloss:0.29637
# [96]	validation_0-logloss:0.29360	validation_1-logloss:0.29592
# [97]	validation_0-logloss:0.29312	validation_1-logloss:0.29547
# [98]	validation_0-logloss:0.29266	validation_1-logloss:0.29504
# [99]	validation_0-logloss:0.29219	validation_1-logloss:0.29460
# [100]	validation_0-logloss:0.29174	validation_1-logloss:0.29417
# [101]	validation_0-logloss:0.29129	validation_1-logloss:0.29375
# [102]	validation_0-logloss:0.29085	validation_1-logloss:0.29333
# [103]	validation_0-logloss:0.29041	validation_1-logloss:0.29291
# [104]	validation_0-logloss:0.28997	validation_1-logloss:0.29250
# [105]	validation_0-logloss:0.28954	validation_1-logloss:0.29210
# [106]	validation_0-logloss:0.28912	validation_1-logloss:0.29170
# [107]	validation_0-logloss:0.28870	validation_1-logloss:0.29130
# [108]	validation_0-logloss:0.28829	validation_1-logloss:0.29092
# [109]	validation_0-logloss:0.28788	validation_1-logloss:0.29053
# [110]	validation_0-logloss:0.28748	validation_1-logloss:0.29015
# [111]	validation_0-logloss:0.28707	validation_1-logloss:0.28977
# [112]	validation_0-logloss:0.28668	validation_1-logloss:0.28940
# [113]	validation_0-logloss:0.28628	validation_1-logloss:0.28903
# [114]	validation_0-logloss:0.28589	validation_1-logloss:0.28866
# [115]	validation_0-logloss:0.28551	validation_1-logloss:0.28830
# [116]	validation_0-logloss:0.28513	validation_1-logloss:0.28794
# [117]	validation_0-logloss:0.28475	validation_1-logloss:0.28759
# [118]	validation_0-logloss:0.28438	validation_1-logloss:0.28724
# [119]	validation_0-logloss:0.28401	validation_1-logloss:0.28690
# [120]	validation_0-logloss:0.28365	validation_1-logloss:0.28656
# [121]	validation_0-logloss:0.28329	validation_1-logloss:0.28622
# [122]	validation_0-logloss:0.28293	validation_1-logloss:0.28589
# [123]	validation_0-logloss:0.28258	validation_1-logloss:0.28556
# [124]	validation_0-logloss:0.28223	validation_1-logloss:0.28523
# [125]	validation_0-logloss:0.28188	validation_1-logloss:0.28490
# [126]	validation_0-logloss:0.28153	validation_1-logloss:0.28458
# [127]	validation_0-logloss:0.28118	validation_1-logloss:0.28426
# [128]	validation_0-logloss:0.28085	validation_1-logloss:0.28394
# [129]	validation_0-logloss:0.28052	validation_1-logloss:0.28364
# [130]	validation_0-logloss:0.28019	validation_1-logloss:0.28333
# [131]	validation_0-logloss:0.27986	validation_1-logloss:0.28303
# [132]	validation_0-logloss:0.27954	validation_1-logloss:0.28273
# [133]	validation_0-logloss:0.27923	validation_1-logloss:0.28244
# [134]	validation_0-logloss:0.27891	validation_1-logloss:0.28215
# [135]	validation_0-logloss:0.27860	validation_1-logloss:0.28186
# [136]	validation_0-logloss:0.27829	validation_1-logloss:0.28158
# [137]	validation_0-logloss:0.27798	validation_1-logloss:0.28129
# [138]	validation_0-logloss:0.27768	validation_1-logloss:0.28101
# [139]	validation_0-logloss:0.27737	validation_1-logloss:0.28073
# [140]	validation_0-logloss:0.27708	validation_1-logloss:0.28046
# [141]	validation_0-logloss:0.27679	validation_1-logloss:0.28019
# [142]	validation_0-logloss:0.27650	validation_1-logloss:0.27992
# [143]	validation_0-logloss:0.27621	validation_1-logloss:0.27966
# [144]	validation_0-logloss:0.27593	validation_1-logloss:0.27940
# [145]	validation_0-logloss:0.27562	validation_1-logloss:0.27911
# [146]	validation_0-logloss:0.27535	validation_1-logloss:0.27886
# [147]	validation_0-logloss:0.27508	validation_1-logloss:0.27861
# [148]	validation_0-logloss:0.27477	validation_1-logloss:0.27833
# [149]	validation_0-logloss:0.27447	validation_1-logloss:0.27806
# [150]	validation_0-logloss:0.27421	validation_1-logloss:0.27782
# [151]	validation_0-logloss:0.27392	validation_1-logloss:0.27755
# [152]	validation_0-logloss:0.27363	validation_1-logloss:0.27729
# [153]	validation_0-logloss:0.27334	validation_1-logloss:0.27703
# [154]	validation_0-logloss:0.27306	validation_1-logloss:0.27677
# [155]	validation_0-logloss:0.27279	validation_1-logloss:0.27652
# [156]	validation_0-logloss:0.27254	validation_1-logloss:0.27630
# [157]	validation_0-logloss:0.27227	validation_1-logloss:0.27605
# [158]	validation_0-logloss:0.27202	validation_1-logloss:0.27583
# [159]	validation_0-logloss:0.27176	validation_1-logloss:0.27559
# [160]	validation_0-logloss:0.27149	validation_1-logloss:0.27535
# [161]	validation_0-logloss:0.27126	validation_1-logloss:0.27514
# [162]	validation_0-logloss:0.27100	validation_1-logloss:0.27491
# [163]	validation_0-logloss:0.27077	validation_1-logloss:0.27470
# [164]	validation_0-logloss:0.27052	validation_1-logloss:0.27447
# [165]	validation_0-logloss:0.27027	validation_1-logloss:0.27424
# [166]	validation_0-logloss:0.27004	validation_1-logloss:0.27404
# [167]	validation_0-logloss:0.26980	validation_1-logloss:0.27382
# [168]	validation_0-logloss:0.26956	validation_1-logloss:0.27361
# [169]	validation_0-logloss:0.26934	validation_1-logloss:0.27341
# [170]	validation_0-logloss:0.26912	validation_1-logloss:0.27322
# [171]	validation_0-logloss:0.26891	validation_1-logloss:0.27302
# [172]	validation_0-logloss:0.26868	validation_1-logloss:0.27282
# [173]	validation_0-logloss:0.26845	validation_1-logloss:0.27261
# [174]	validation_0-logloss:0.26824	validation_1-logloss:0.27243
# [175]	validation_0-logloss:0.26803	validation_1-logloss:0.27224
# [176]	validation_0-logloss:0.26781	validation_1-logloss:0.27204
# [177]	validation_0-logloss:0.26760	validation_1-logloss:0.27186
# [178]	validation_0-logloss:0.26740	validation_1-logloss:0.27168
# [179]	validation_0-logloss:0.26718	validation_1-logloss:0.27149
# [180]	validation_0-logloss:0.26697	validation_1-logloss:0.27130
# [181]	validation_0-logloss:0.26678	validation_1-logloss:0.27113
# [182]	validation_0-logloss:0.26658	validation_1-logloss:0.27096
# [183]	validation_0-logloss:0.26640	validation_1-logloss:0.27079
# [184]	validation_0-logloss:0.26619	validation_1-logloss:0.27061
# [185]	validation_0-logloss:0.26599	validation_1-logloss:0.27043
# [186]	validation_0-logloss:0.26580	validation_1-logloss:0.27027
# [187]	validation_0-logloss:0.26560	validation_1-logloss:0.27008
# [188]	validation_0-logloss:0.26542	validation_1-logloss:0.26992
# [189]	validation_0-logloss:0.26522	validation_1-logloss:0.26975
# [190]	validation_0-logloss:0.26504	validation_1-logloss:0.26960
# [191]	validation_0-logloss:0.26486	validation_1-logloss:0.26944
# [192]	validation_0-logloss:0.26468	validation_1-logloss:0.26928
# [193]	validation_0-logloss:0.26449	validation_1-logloss:0.26911
# [194]	validation_0-logloss:0.26431	validation_1-logloss:0.26895
# [195]	validation_0-logloss:0.26414	validation_1-logloss:0.26880
# [196]	validation_0-logloss:0.26396	validation_1-logloss:0.26865
# [197]	validation_0-logloss:0.26378	validation_1-logloss:0.26849
# [198]	validation_0-logloss:0.26362	validation_1-logloss:0.26835
# [199]	validation_0-logloss:0.26344	validation_1-logloss:0.26820
# [200]	validation_0-logloss:0.26327	validation_1-logloss:0.26805
# [201]	validation_0-logloss:0.26311	validation_1-logloss:0.26791
# [202]	validation_0-logloss:0.26294	validation_1-logloss:0.26776
# [203]	validation_0-logloss:0.26278	validation_1-logloss:0.26763
# [204]	validation_0-logloss:0.26262	validation_1-logloss:0.26749
# [205]	validation_0-logloss:0.26246	validation_1-logloss:0.26735
# [206]	validation_0-logloss:0.26229	validation_1-logloss:0.26721
# [207]	validation_0-logloss:0.26214	validation_1-logloss:0.26707
# [208]	validation_0-logloss:0.26197	validation_1-logloss:0.26693
# [209]	validation_0-logloss:0.26182	validation_1-logloss:0.26680
# [210]	validation_0-logloss:0.26167	validation_1-logloss:0.26667
# [211]	validation_0-logloss:0.26152	validation_1-logloss:0.26655
# [212]	validation_0-logloss:0.26137	validation_1-logloss:0.26641
# [213]	validation_0-logloss:0.26122	validation_1-logloss:0.26629
# [214]	validation_0-logloss:0.26108	validation_1-logloss:0.26617
# [215]	validation_0-logloss:0.26093	validation_1-logloss:0.26603
# [216]	validation_0-logloss:0.26079	validation_1-logloss:0.26591
# [217]	validation_0-logloss:0.26063	validation_1-logloss:0.26578
# [218]	validation_0-logloss:0.26049	validation_1-logloss:0.26566
# [219]	validation_0-logloss:0.26035	validation_1-logloss:0.26554
# [220]	validation_0-logloss:0.26022	validation_1-logloss:0.26542
# [221]	validation_0-logloss:0.26009	validation_1-logloss:0.26531
# [222]	validation_0-logloss:0.25996	validation_1-logloss:0.26520
# [223]	validation_0-logloss:0.25983	validation_1-logloss:0.26509
# [224]	validation_0-logloss:0.25968	validation_1-logloss:0.26497
# [225]	validation_0-logloss:0.25955	validation_1-logloss:0.26486
# [226]	validation_0-logloss:0.25943	validation_1-logloss:0.26475
# [227]	validation_0-logloss:0.25929	validation_1-logloss:0.26463
# [228]	validation_0-logloss:0.25917	validation_1-logloss:0.26453
# [229]	validation_0-logloss:0.25903	validation_1-logloss:0.26441
# [230]	validation_0-logloss:0.25891	validation_1-logloss:0.26431
# [231]	validation_0-logloss:0.25878	validation_1-logloss:0.26420
# [232]	validation_0-logloss:0.25865	validation_1-logloss:0.26410
# [233]	validation_0-logloss:0.25854	validation_1-logloss:0.26400
# [234]	validation_0-logloss:0.25841	validation_1-logloss:0.26389
# [235]	validation_0-logloss:0.25829	validation_1-logloss:0.26379
# [236]	validation_0-logloss:0.25816	validation_1-logloss:0.26368
# [237]	validation_0-logloss:0.25803	validation_1-logloss:0.26357
# [238]	validation_0-logloss:0.25792	validation_1-logloss:0.26348
# [239]	validation_0-logloss:0.25780	validation_1-logloss:0.26338
# [240]	validation_0-logloss:0.25768	validation_1-logloss:0.26328
# [241]	validation_0-logloss:0.25755	validation_1-logloss:0.26318
# [242]	validation_0-logloss:0.25745	validation_1-logloss:0.26309
# [243]	validation_0-logloss:0.25734	validation_1-logloss:0.26300
# [244]	validation_0-logloss:0.25723	validation_1-logloss:0.26291
# [245]	validation_0-logloss:0.25710	validation_1-logloss:0.26281
# [246]	validation_0-logloss:0.25700	validation_1-logloss:0.26272
# [247]	validation_0-logloss:0.25689	validation_1-logloss:0.26264
# [248]	validation_0-logloss:0.25678	validation_1-logloss:0.26254
# [249]	validation_0-logloss:0.25667	validation_1-logloss:0.26246
# [250]	validation_0-logloss:0.25655	validation_1-logloss:0.26237
# [251]	validation_0-logloss:0.25645	validation_1-logloss:0.26228
# [252]	validation_0-logloss:0.25634	validation_1-logloss:0.26219
# [253]	validation_0-logloss:0.25624	validation_1-logloss:0.26211
# [254]	validation_0-logloss:0.25613	validation_1-logloss:0.26203
# [255]	validation_0-logloss:0.25603	validation_1-logloss:0.26194
# [256]	validation_0-logloss:0.25593	validation_1-logloss:0.26187
# [257]	validation_0-logloss:0.25582	validation_1-logloss:0.26178
# [258]	validation_0-logloss:0.25572	validation_1-logloss:0.26170
# [259]	validation_0-logloss:0.25563	validation_1-logloss:0.26162
# [260]	validation_0-logloss:0.25551	validation_1-logloss:0.26154
# [261]	validation_0-logloss:0.25542	validation_1-logloss:0.26146
# [262]	validation_0-logloss:0.25531	validation_1-logloss:0.26137
# [263]	validation_0-logloss:0.25522	validation_1-logloss:0.26130
# [264]	validation_0-logloss:0.25511	validation_1-logloss:0.26121
# [265]	validation_0-logloss:0.25501	validation_1-logloss:0.26113
# [266]	validation_0-logloss:0.25490	validation_1-logloss:0.26105
# [267]	validation_0-logloss:0.25480	validation_1-logloss:0.26097
# [268]	validation_0-logloss:0.25471	validation_1-logloss:0.26090
# [269]	validation_0-logloss:0.25463	validation_1-logloss:0.26083
# [270]	validation_0-logloss:0.25453	validation_1-logloss:0.26075
# [271]	validation_0-logloss:0.25444	validation_1-logloss:0.26069
# [272]	validation_0-logloss:0.25434	validation_1-logloss:0.26061
# [273]	validation_0-logloss:0.25425	validation_1-logloss:0.26055
# [274]	validation_0-logloss:0.25417	validation_1-logloss:0.26048
# [275]	validation_0-logloss:0.25408	validation_1-logloss:0.26041
# [276]	validation_0-logloss:0.25398	validation_1-logloss:0.26033
# [277]	validation_0-logloss:0.25389	validation_1-logloss:0.26026
# [278]	validation_0-logloss:0.25380	validation_1-logloss:0.26019
# [279]	validation_0-logloss:0.25371	validation_1-logloss:0.26013
# [280]	validation_0-logloss:0.25363	validation_1-logloss:0.26006
# [281]	validation_0-logloss:0.25354	validation_1-logloss:0.26000
# [282]	validation_0-logloss:0.25346	validation_1-logloss:0.25993
# [283]	validation_0-logloss:0.25338	validation_1-logloss:0.25987
# [284]	validation_0-logloss:0.25330	validation_1-logloss:0.25982
# [285]	validation_0-logloss:0.25322	validation_1-logloss:0.25975
# [286]	validation_0-logloss:0.25313	validation_1-logloss:0.25969
# [287]	validation_0-logloss:0.25305	validation_1-logloss:0.25963
# [288]	validation_0-logloss:0.25297	validation_1-logloss:0.25957
# [289]	validation_0-logloss:0.25289	validation_1-logloss:0.25951
# [290]	validation_0-logloss:0.25281	validation_1-logloss:0.25945
# [291]	validation_0-logloss:0.25274	validation_1-logloss:0.25940
# [292]	validation_0-logloss:0.25266	validation_1-logloss:0.25934
# [293]	validation_0-logloss:0.25258	validation_1-logloss:0.25928
# [294]	validation_0-logloss:0.25251	validation_1-logloss:0.25923
# [295]	validation_0-logloss:0.25242	validation_1-logloss:0.25916
# [296]	validation_0-logloss:0.25234	validation_1-logloss:0.25910
# [297]	validation_0-logloss:0.25226	validation_1-logloss:0.25904
# [298]	validation_0-logloss:0.25219	validation_1-logloss:0.25899
# [299]	validation_0-logloss:0.25211	validation_1-logloss:0.25893
# [300]	validation_0-logloss:0.25204	validation_1-logloss:0.25888
# [301]	validation_0-logloss:0.25196	validation_1-logloss:0.25882
# [302]	validation_0-logloss:0.25189	validation_1-logloss:0.25877
# [303]	validation_0-logloss:0.25182	validation_1-logloss:0.25872
# [304]	validation_0-logloss:0.25175	validation_1-logloss:0.25866
# [305]	validation_0-logloss:0.25168	validation_1-logloss:0.25861
# [306]	validation_0-logloss:0.25161	validation_1-logloss:0.25856
# [307]	validation_0-logloss:0.25154	validation_1-logloss:0.25852
# [308]	validation_0-logloss:0.25147	validation_1-logloss:0.25846
# [309]	validation_0-logloss:0.25140	validation_1-logloss:0.25841
# [310]	validation_0-logloss:0.25134	validation_1-logloss:0.25837
# [311]	validation_0-logloss:0.25127	validation_1-logloss:0.25832
# [312]	validation_0-logloss:0.25119	validation_1-logloss:0.25826
# [313]	validation_0-logloss:0.25113	validation_1-logloss:0.25822
# [314]	validation_0-logloss:0.25107	validation_1-logloss:0.25817
# [315]	validation_0-logloss:0.25100	validation_1-logloss:0.25812
# [316]	validation_0-logloss:0.25093	validation_1-logloss:0.25807
# [317]	validation_0-logloss:0.25087	validation_1-logloss:0.25803
# [318]	validation_0-logloss:0.25079	validation_1-logloss:0.25797
# [319]	validation_0-logloss:0.25073	validation_1-logloss:0.25793
# [320]	validation_0-logloss:0.25067	validation_1-logloss:0.25788
# [321]	validation_0-logloss:0.25060	validation_1-logloss:0.25784
# [322]	validation_0-logloss:0.25053	validation_1-logloss:0.25779
# [323]	validation_0-logloss:0.25047	validation_1-logloss:0.25775
# [324]	validation_0-logloss:0.25040	validation_1-logloss:0.25770
# [325]	validation_0-logloss:0.25034	validation_1-logloss:0.25765
# [326]	validation_0-logloss:0.25027	validation_1-logloss:0.25760
# [327]	validation_0-logloss:0.25021	validation_1-logloss:0.25756
# [328]	validation_0-logloss:0.25014	validation_1-logloss:0.25751
# [329]	validation_0-logloss:0.25008	validation_1-logloss:0.25747
# [330]	validation_0-logloss:0.25002	validation_1-logloss:0.25743
# [331]	validation_0-logloss:0.24996	validation_1-logloss:0.25739
# [332]	validation_0-logloss:0.24991	validation_1-logloss:0.25736
# [333]	validation_0-logloss:0.24984	validation_1-logloss:0.25731
# [334]	validation_0-logloss:0.24978	validation_1-logloss:0.25727
# [335]	validation_0-logloss:0.24972	validation_1-logloss:0.25723
# [336]	validation_0-logloss:0.24966	validation_1-logloss:0.25719
# [337]	validation_0-logloss:0.24960	validation_1-logloss:0.25715
# [338]	validation_0-logloss:0.24955	validation_1-logloss:0.25711
# [339]	validation_0-logloss:0.24948	validation_1-logloss:0.25707
# [340]	validation_0-logloss:0.24943	validation_1-logloss:0.25703
# [341]	validation_0-logloss:0.24938	validation_1-logloss:0.25699
# [342]	validation_0-logloss:0.24932	validation_1-logloss:0.25695
# [343]	validation_0-logloss:0.24927	validation_1-logloss:0.25692
# [344]	validation_0-logloss:0.24920	validation_1-logloss:0.25687
# [345]	validation_0-logloss:0.24915	validation_1-logloss:0.25684
# [346]	validation_0-logloss:0.24910	validation_1-logloss:0.25681
# [347]	validation_0-logloss:0.24904	validation_1-logloss:0.25677
# [348]	validation_0-logloss:0.24899	validation_1-logloss:0.25674
# [349]	validation_0-logloss:0.24894	validation_1-logloss:0.25670
# [350]	validation_0-logloss:0.24888	validation_1-logloss:0.25666
# [351]	validation_0-logloss:0.24884	validation_1-logloss:0.25663
# [352]	validation_0-logloss:0.24877	validation_1-logloss:0.25659
# [353]	validation_0-logloss:0.24872	validation_1-logloss:0.25656
# [354]	validation_0-logloss:0.24868	validation_1-logloss:0.25653
# [355]	validation_0-logloss:0.24861	validation_1-logloss:0.25648
# [356]	validation_0-logloss:0.24856	validation_1-logloss:0.25645
# [357]	validation_0-logloss:0.24852	validation_1-logloss:0.25642
# [358]	validation_0-logloss:0.24846	validation_1-logloss:0.25638
# [359]	validation_0-logloss:0.24841	validation_1-logloss:0.25635
# [360]	validation_0-logloss:0.24837	validation_1-logloss:0.25632
# [361]	validation_0-logloss:0.24831	validation_1-logloss:0.25629
# [362]	validation_0-logloss:0.24827	validation_1-logloss:0.25626
# [363]	validation_0-logloss:0.24822	validation_1-logloss:0.25623
# [364]	validation_0-logloss:0.24816	validation_1-logloss:0.25619
# [365]	validation_0-logloss:0.24812	validation_1-logloss:0.25617
# [366]	validation_0-logloss:0.24808	validation_1-logloss:0.25614
# [367]	validation_0-logloss:0.24802	validation_1-logloss:0.25610
# [368]	validation_0-logloss:0.24798	validation_1-logloss:0.25608
# [369]	validation_0-logloss:0.24793	validation_1-logloss:0.25605
# [370]	validation_0-logloss:0.24789	validation_1-logloss:0.25602
# [371]	validation_0-logloss:0.24783	validation_1-logloss:0.25599
# [372]	validation_0-logloss:0.24779	validation_1-logloss:0.25596
# [373]	validation_0-logloss:0.24775	validation_1-logloss:0.25594
# [374]	validation_0-logloss:0.24770	validation_1-logloss:0.25591
# [375]	validation_0-logloss:0.24767	validation_1-logloss:0.25588
# [376]	validation_0-logloss:0.24762	validation_1-logloss:0.25585
# [377]	validation_0-logloss:0.24758	validation_1-logloss:0.25583
# [378]	validation_0-logloss:0.24753	validation_1-logloss:0.25580
# [379]	validation_0-logloss:0.24747	validation_1-logloss:0.25577
# [380]	validation_0-logloss:0.24743	validation_1-logloss:0.25575
# [381]	validation_0-logloss:0.24737	validation_1-logloss:0.25572
# [382]	validation_0-logloss:0.24732	validation_1-logloss:0.25570
# [383]	validation_0-logloss:0.24728	validation_1-logloss:0.25567
# [384]	validation_0-logloss:0.24722	validation_1-logloss:0.25565
# [385]	validation_0-logloss:0.24718	validation_1-logloss:0.25563
# [386]	validation_0-logloss:0.24713	validation_1-logloss:0.25559
# [387]	validation_0-logloss:0.24708	validation_1-logloss:0.25557
# [388]	validation_0-logloss:0.24704	validation_1-logloss:0.25555
# [389]	validation_0-logloss:0.24699	validation_1-logloss:0.25553
# [390]	validation_0-logloss:0.24694	validation_1-logloss:0.25550
# [391]	validation_0-logloss:0.24690	validation_1-logloss:0.25548
# [392]	validation_0-logloss:0.24685	validation_1-logloss:0.25545
# [393]	validation_0-logloss:0.24680	validation_1-logloss:0.25542
# [394]	validation_0-logloss:0.24676	validation_1-logloss:0.25540
# [395]	validation_0-logloss:0.24671	validation_1-logloss:0.25538
# [396]	validation_0-logloss:0.24667	validation_1-logloss:0.25535
# [397]	validation_0-logloss:0.24661	validation_1-logloss:0.25532
# [398]	validation_0-logloss:0.24657	validation_1-logloss:0.25530
# [399]	validation_0-logloss:0.24653	validation_1-logloss:0.25527
# [400]	validation_0-logloss:0.24648	validation_1-logloss:0.25525
# [401]	validation_0-logloss:0.24644	validation_1-logloss:0.25523
# [402]	validation_0-logloss:0.24639	validation_1-logloss:0.25521
# [403]	validation_0-logloss:0.24635	validation_1-logloss:0.25518
# [404]	validation_0-logloss:0.24631	validation_1-logloss:0.25516
# [405]	validation_0-logloss:0.24626	validation_1-logloss:0.25514
# [406]	validation_0-logloss:0.24622	validation_1-logloss:0.25512
# [407]	validation_0-logloss:0.24618	validation_1-logloss:0.25510
# [408]	validation_0-logloss:0.24614	validation_1-logloss:0.25508
# [409]	validation_0-logloss:0.24610	validation_1-logloss:0.25506
# [410]	validation_0-logloss:0.24606	validation_1-logloss:0.25504
# [411]	validation_0-logloss:0.24602	validation_1-logloss:0.25501
# [412]	validation_0-logloss:0.24597	validation_1-logloss:0.25499
# [413]	validation_0-logloss:0.24593	validation_1-logloss:0.25497
# [414]	validation_0-logloss:0.24588	validation_1-logloss:0.25494
# [415]	validation_0-logloss:0.24584	validation_1-logloss:0.25493
# [416]	validation_0-logloss:0.24580	validation_1-logloss:0.25490
# [417]	validation_0-logloss:0.24576	validation_1-logloss:0.25488
# [418]	validation_0-logloss:0.24571	validation_1-logloss:0.25486
# [419]	validation_0-logloss:0.24567	validation_1-logloss:0.25484
# [420]	validation_0-logloss:0.24563	validation_1-logloss:0.25482
# [421]	validation_0-logloss:0.24559	validation_1-logloss:0.25480
# [422]	validation_0-logloss:0.24554	validation_1-logloss:0.25478
# [423]	validation_0-logloss:0.24551	validation_1-logloss:0.25476
# [424]	validation_0-logloss:0.24546	validation_1-logloss:0.25473
# [425]	validation_0-logloss:0.24542	validation_1-logloss:0.25471
# [426]	validation_0-logloss:0.24539	validation_1-logloss:0.25470
# [427]	validation_0-logloss:0.24536	validation_1-logloss:0.25468
# [428]	validation_0-logloss:0.24532	validation_1-logloss:0.25466
# [429]	validation_0-logloss:0.24530	validation_1-logloss:0.25465
# [430]	validation_0-logloss:0.24526	validation_1-logloss:0.25463
# [431]	validation_0-logloss:0.24523	validation_1-logloss:0.25461
# [432]	validation_0-logloss:0.24519	validation_1-logloss:0.25459
# [433]	validation_0-logloss:0.24516	validation_1-logloss:0.25458
# [434]	validation_0-logloss:0.24513	validation_1-logloss:0.25456
# [435]	validation_0-logloss:0.24510	validation_1-logloss:0.25455
# [436]	validation_0-logloss:0.24506	validation_1-logloss:0.25453
# [437]	validation_0-logloss:0.24503	validation_1-logloss:0.25451
# [438]	validation_0-logloss:0.24500	validation_1-logloss:0.25450
# [439]	validation_0-logloss:0.24496	validation_1-logloss:0.25448
# [440]	validation_0-logloss:0.24493	validation_1-logloss:0.25446
# [441]	validation_0-logloss:0.24489	validation_1-logloss:0.25445
# [442]	validation_0-logloss:0.24486	validation_1-logloss:0.25443
# [443]	validation_0-logloss:0.24483	validation_1-logloss:0.25441
# [444]	validation_0-logloss:0.24480	validation_1-logloss:0.25440
# [445]	validation_0-logloss:0.24477	validation_1-logloss:0.25438
# [446]	validation_0-logloss:0.24474	validation_1-logloss:0.25437
# [447]	validation_0-logloss:0.24470	validation_1-logloss:0.25435
# [448]	validation_0-logloss:0.24467	validation_1-logloss:0.25434
# [449]	validation_0-logloss:0.24464	validation_1-logloss:0.25432
# [450]	validation_0-logloss:0.24461	validation_1-logloss:0.25431
# [451]	validation_0-logloss:0.24457	validation_1-logloss:0.25429
# [452]	validation_0-logloss:0.24454	validation_1-logloss:0.25428
# [453]	validation_0-logloss:0.24451	validation_1-logloss:0.25426
# [454]	validation_0-logloss:0.24449	validation_1-logloss:0.25425
# [455]	validation_0-logloss:0.24445	validation_1-logloss:0.25424
# [456]	validation_0-logloss:0.24443	validation_1-logloss:0.25422
# [457]	validation_0-logloss:0.24439	validation_1-logloss:0.25421
# [458]	validation_0-logloss:0.24437	validation_1-logloss:0.25420
# [459]	validation_0-logloss:0.24434	validation_1-logloss:0.25418
# [460]	validation_0-logloss:0.24430	validation_1-logloss:0.25417
# [461]	validation_0-logloss:0.24427	validation_1-logloss:0.25416
# [462]	validation_0-logloss:0.24424	validation_1-logloss:0.25414
# [463]	validation_0-logloss:0.24422	validation_1-logloss:0.25413
# [464]	validation_0-logloss:0.24418	validation_1-logloss:0.25412
# [465]	validation_0-logloss:0.24416	validation_1-logloss:0.25410
# [466]	validation_0-logloss:0.24413	validation_1-logloss:0.25409
# [467]	validation_0-logloss:0.24410	validation_1-logloss:0.25408
# [468]	validation_0-logloss:0.24407	validation_1-logloss:0.25407
# [469]	validation_0-logloss:0.24404	validation_1-logloss:0.25406
# [470]	validation_0-logloss:0.24402	validation_1-logloss:0.25405
# [471]	validation_0-logloss:0.24399	validation_1-logloss:0.25403
# [472]	validation_0-logloss:0.24396	validation_1-logloss:0.25402
# [473]	validation_0-logloss:0.24393	validation_1-logloss:0.25401
# [474]	validation_0-logloss:0.24390	validation_1-logloss:0.25400
# [475]	validation_0-logloss:0.24388	validation_1-logloss:0.25399
# [476]	validation_0-logloss:0.24385	validation_1-logloss:0.25398
# [477]	validation_0-logloss:0.24382	validation_1-logloss:0.25396
# [478]	validation_0-logloss:0.24380	validation_1-logloss:0.25395
# [479]	validation_0-logloss:0.24377	validation_1-logloss:0.25394
# [480]	validation_0-logloss:0.24374	validation_1-logloss:0.25393
# [481]	validation_0-logloss:0.24372	validation_1-logloss:0.25392
# [482]	validation_0-logloss:0.24369	validation_1-logloss:0.25391
# [483]	validation_0-logloss:0.24367	validation_1-logloss:0.25390
# [484]	validation_0-logloss:0.24364	validation_1-logloss:0.25389
# [485]	validation_0-logloss:0.24361	validation_1-logloss:0.25388
# [486]	validation_0-logloss:0.24357	validation_1-logloss:0.25387
# [487]	validation_0-logloss:0.24355	validation_1-logloss:0.25386
# [488]	validation_0-logloss:0.24352	validation_1-logloss:0.25385
# [489]	validation_0-logloss:0.24348	validation_1-logloss:0.25384
# [490]	validation_0-logloss:0.24345	validation_1-logloss:0.25383
# [491]	validation_0-logloss:0.24342	validation_1-logloss:0.25382
# [492]	validation_0-logloss:0.24339	validation_1-logloss:0.25381
# [493]	validation_0-logloss:0.24336	validation_1-logloss:0.25380
# [494]	validation_0-logloss:0.24333	validation_1-logloss:0.25379
# [495]	validation_0-logloss:0.24330	validation_1-logloss:0.25378
# [496]	validation_0-logloss:0.24326	validation_1-logloss:0.25376
# [497]	validation_0-logloss:0.24323	validation_1-logloss:0.25375
# [498]	validation_0-logloss:0.24319	validation_1-logloss:0.25374
# [499]	validation_0-logloss:0.24317	validation_1-logloss:0.25373
# roc auc value: 0.5358381985415641

# %% [markdown]
# ## Save the xgboost model

# %%
import joblib

joblib.dump(xgboost_model, 'models/xgboost_model.pkl')
# Out:
# ['models/xgboost_model.pkl']

# %%
import joblib

xgboost_model = joblib.load('models/xgboost_model.pkl')

# %% [markdown]
# ## Train the Catboost

# %%
# from sklearn.model_selection import train_test_split

# # Preprocessing the data
# train_data = Dataset(config.train_path)
# train_df_cate, categorical_columns = train_data.preprocessing_category()

# train_df_cate = train_df_cate.drop('id', axis=1)

# y = train_df_cate['Response']
# X = train_df_cate.drop('Response', axis=1)

# X_train_cate, X_test_cate, y_train_cate, y_test_cate = train_test_split(X, y, test_size=0.2, random_state=41)
# Out:
# Load the data...
# Preprocess the data
# Finished!
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from catboost import CatBoostClassifier
from sklearn.metrics import roc_auc_score

# cat_features = [train_df_cate.columns.get_loc(col) for col in categorical_columns]

catboost_model = CatBoostClassifier(iterations=500,
                        #    cat_features=cat_features,
                           depth=16,
                           learning_rate=0.01,
                           loss_function='Logloss',
                           random_state=41, 
                           verbose=True)

catboost_model.fit(X_train, y_train)

# Evaluate the model on the test data (optional)
y_pred = catboost_model.predict(X_test)
auc = roc_auc_score(y_test, y_pred)
print(f"roc auc value: {auc}")
# Out:
# 0:	learn: 0.6717141	total: 4.91s	remaining: 40m 49s
# 1:	learn: 0.6514689	total: 7.1s	remaining: 29m 28s
# 2:	learn: 0.6320136	total: 11.4s	remaining: 31m 31s
# 3:	learn: 0.6136876	total: 15.7s	remaining: 32m 24s
# 4:	learn: 0.5962660	total: 20.4s	remaining: 33m 38s
# 5:	learn: 0.5797863	total: 22.6s	remaining: 31m 4s
# 6:	learn: 0.5640910	total: 27.2s	remaining: 31m 57s
# 7:	learn: 0.5491933	total: 31.4s	remaining: 32m 10s
# 8:	learn: 0.5350538	total: 35.5s	remaining: 32m 17s
# 9:	learn: 0.5216996	total: 39.7s	remaining: 32m 25s
# 10:	learn: 0.5091697	total: 43.9s	remaining: 32m 31s
# 11:	learn: 0.4973134	total: 48.3s	remaining: 32m 44s

# %% [markdown]
# ## Save the catboost model

# %%
import joblib

joblib.dump(catboost_model, 'models/catboost_model.pkl')
# Out:
# ['models/catboost_model.pkl']

# %%
import joblib

catboost_model = joblib.load('models/catboost_model.pkl')

# %% [markdown]
# ## Probability

# %%
lgbm_proba = pd.Series(lgbm_model.predict_proba(X_test)[:, 1], name='lgbm')
xgboost_proba = pd.Series(xgboost_model.predict_proba(X_test)[:, 1], name='xgboost')
catboost_proba = pd.Series(catboost_model.predict_proba(X_test_cate)[:, 1], name='catboost')

result = pd.concat([lgbm_proba, catboost_proba, xgboost_proba], axis=1)
result.head(5)
# Out:
#        lgbm  catboost   xgboost
# 0  0.172179  0.369445  0.156010
# 1  0.000149  0.302822  0.001345
# 2  0.000157  0.302817  0.001345
# 3  0.326306  0.426290  0.423770
# 4  0.000166  0.302821  0.001345

# %% [markdown]
# ## Train the Neural Network

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import RobustScaler

# Standardizing the features
scaler = RobustScaler() # Premium, Age만 사용 나머지는 Standard Scaler 로 진행하기.
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Define the neural network model
nn_model = Sequential([
    Dense(64, activation='relu', input_shape=(3,)),
    Dense(32, activation='relu'),
    Dense(32, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile the model
nn_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[tf.keras.metrics.AUC()])

# Fit the model
nn_model.fit(result, y_test, epochs=10, batch_size=128, validation_data=(result, y_test))

# Evaluate the model on the test data
y_pred = nn_model.predict(result)

accuracy = roc_auc_score(y_test, y_pred)
print(f"roc auc value: {auc}")
# Out:
# 2024-07-26 18:37:29.100051: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-26 18:37:29.891281: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Epoch 1/10
# 2024-07-26 18:37:33.264798: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2b:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-07-26 18:37:33.498828: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 17977/17977 [==============================] - 25s 1ms/step - loss: 0.2536 - auc: 0.8768 - val_loss: 0.2526 - val_auc: 0.8788
# Epoch 2/10
# 17977/17977 [==============================] - 24s 1ms/step - loss: 0.2521 - auc: 0.8787 - val_loss: 0.2516 - val_auc: 0.8795
# Epoch 3/10
# 17977/17977 [==============================] - 24s 1ms/step - loss: 0.2519 - auc: 0.8789 - val_loss: 0.2517 - val_auc: 0.8794
# Epoch 4/10
# 17977/17977 [==============================] - 24s 1ms/step - loss: 0.2519 - auc: 0.8790 - val_loss: 0.2516 - val_auc: 0.8794
# Epoch 5/10
# 17977/17977 [==============================] - 24s 1ms/step - loss: 0.2518 - auc: 0.8791 - val_loss: 0.2520 - val_auc: 0.8795
# Epoch 6/10
# 17977/17977 [==============================] - 24s 1ms/step - loss: 0.2518 - auc: 0.8791 - val_loss: 0.2515 - val_auc: 0.8795
# Epoch 7/10
# 17977/17977 [==============================] - 24s 1ms/step - loss: 0.2518 - auc: 0.8791 - val_loss: 0.2517 - val_auc: 0.8795
# Epoch 8/10
# 17977/17977 [==============================] - 24s 1ms/step - loss: 0.2517 - auc: 0.8791 - val_loss: 0.2515 - val_auc: 0.8795
# Epoch 9/10
# 17977/17977 [==============================] - 24s 1ms/step - loss: 0.2517 - auc: 0.8792 - val_loss: 0.2516 - val_auc: 0.8794
# Epoch 10/10
# 17977/17977 [==============================] - 24s 1ms/step - loss: 0.2517 - auc: 0.8792 - val_loss: 0.2518 - val_auc: 0.8795
# 71905/71905 [==============================] - 35s 484us/step
# roc auc value: 0.5

# %%
y_pred.shape
# Out:
# (2300960, 1)

# %% [markdown]
# ## Load test data

# %%
# Preprocessing the data
test_data = Dataset(config.test_path)
test_df = test_data.preprocessing()
test_df = test_df.drop('id', axis=1)
# Out:
# Load the data...
# Preprocess the data
# Finished!

# %%
test_data.head(5)
# Out:
#          id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0  11504798  Female   20                1         47.0                   0
# 1  11504799    Male   47                1         28.0                   0
# 2  11504800    Male   47                1         43.0                   0
# 3  11504801  Female   22                1         47.0                   1
# 4  11504802    Male   51                1         19.0                   0
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage
# 0    < 1 Year             No          2630.0                 160.0      228
# 1    1-2 Year            Yes         37483.0                 124.0      123
# 2    1-2 Year            Yes          2630.0                  26.0      271
# 3    < 1 Year             No         24502.0                 152.0      115
# 4    1-2 Year             No         34115.0                 124.0      148

# %% [markdown]
# ## Make submission.csv

# %%
lgbm_proba = pd.Series(lgbm_model.predict_proba(test_df)[:, 1], name='lgbm')
catboost_proba = pd.Series(catboost_model.predict_proba(test_df)[:, 1], name='catboost')
xgboost_proba = pd.Series(xgboost_model.predict_proba(test_df)[:, 1], name='xgboost')

print('Finished tree model inference!')

result = pd.concat([lgbm_proba, catboost_proba, xgboost_proba], axis=1)
y_pred = nn_model.predict(result)
# Out:
# Finished tree model inference!
# 239684/239684 [==============================] - 122s 507us/step

# %%
id_ = test_data.preprocessing()
submission = pd.DataFrame({'id': id_['id'], 'Response': y_pred[:, 0]})

submission.to_csv('submission.csv', index=False)
print('Predictions saved to submission.csv')
# Out:
# Preprocess the data
# Finished!
# Predictions saved to submission.csv
